# %% [markdown]
# # 0. 세팅

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import random
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

game_round = 10
strategies = ["Copycat", "All Cooperate", "All Cheat", "Grudger", "Detective", 
              "Copykitten", "Simpleton", "Random", "Cheat-Downing", "Cooperate-Downing", 
              "Joss", "Cheat-Tester", "Cooperate-Tester", "Tranquilizer", "Gradual", 
              "Prober", "Pavlov", "Mistrust", "Per-Kind", "Per-Nasty"]

# %%
class REINFORCE(nn.Module):
    def __init__(self):
        super(REINFORCE, self).__init__()
        self.data = []
        
        self.fc1 = nn.Linear(game_round * 2, 128)
        self.fc2 = nn.Linear(128, 2)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.softmax(self.fc2(x), dim=0)
        return x

# %%
def reward(my_action, opponent_action):
    if [my_action, opponent_action] == [1, 1]: # 협력, 협력
        return 2
    elif [my_action, opponent_action] == [1, 0]: # 협력, 배신
        return -1
    elif [my_action, opponent_action] == [0, 1]: # 배신, 협력
        return 3
    elif [my_action, opponent_action] == [0, 0]: # 배신, 배신
        return 0

# %%
def get_action_of_agent(agent, state, order):
    if order == 1:
        prob = agent(torch.tensor(state).float())
    elif order == 2:
        state_ = []
        for i in range(0, len(state), 2):
            state_.append(state[i+1])
            state_.append(state[i])
        prob = agent(torch.tensor(state_).float())

    return int(torch.argmax(prob))

# %%
def get_action_of_strategy(state, strategy, order):
    my_state = []
    opp_state = []
    for i, s in enumerate(state):
        if s == -1:
            cur_game_round = i // 2
            break
        if order == 1:
            if i % 2 == 0:
                my_state.append(s)
            else:
                opp_state.append(s)
        elif order == 2:
            if i % 2 == 0:
                opp_state.append(s)
            else:
                my_state.append(s)

    if strategy == "Copycat":
        if cur_game_round == 0:
            my_action = 1
        else:
            prev_opp_action = opp_state[-1]
            my_action = prev_opp_action

    elif strategy == "All Cooperate":
        my_action = 1

    elif strategy == "All Cheat":
        my_action = 0

    elif strategy == "Grudger":
        if cur_game_round == 0:
            my_action = 1
        else:
            my_action = 1 if 0 not in opp_state else 0

    elif strategy == "Detective":
        if cur_game_round in [0, 2, 3]:
            my_action = 1
        elif cur_game_round == 1:
            my_action = 0
        else:
            if 0 in opp_state[:4]:
                prev_opp_action = opp_state[-1]
                my_action = prev_opp_action
            else:
                my_action = 0

    elif strategy == "Copykitten":
        if cur_game_round in [0, 1]:
            my_action = 1
        else:
            prev_prev_opp_action, prev_opp_action = opp_state[-2], opp_state[-1]
            my_action = 0 if [prev_prev_opp_action, prev_opp_action] == [0, 0] else 1

    elif strategy == "Simpleton":
        if cur_game_round == 0:
            my_action = 1
        else:
            prev_action, prev_opp_action = my_state[-1], opp_state[-1]
            if prev_opp_action == 0:
                if prev_action == 0:
                    my_action = 1
                else:
                    my_action = 0
            else:
                my_action = prev_action

    elif strategy == "Random":
        my_action = random.randint(0, 1)

    elif strategy == "Cheat-Downing":
        opp_coop, opp_cheat = 0, 0
        for os in opp_state:      
            if os == 0:
                opp_cheat += 1
            else:
                opp_coop += 1
        if opp_cheat >= opp_coop:
            my_action = 0
        else:
            my_action = 1                

    elif strategy == "Cooperate-Downing":
        opp_coop, opp_cheat = 0, 0
        for os in opp_state:      
            if os == 0:
                opp_cheat += 1
            else:
                opp_coop += 1
        if opp_cheat > opp_coop:
            my_action = 0
        else:
            my_action = 1
    
    elif strategy == "Joss":
        if cur_game_round == 0:
            prob = random.randint(0, 9)
            if prob == 0:
                my_action = 0
            else:
              my_action = 1
        else:
            prev_opp_action = opp_state[-1]
            my_action = prev_opp_action

    elif strategy == "Cheat-Tester":
        if cur_game_round < game_round // 2:
            my_action = random.randint(0, 1)
        else:
            opp_coop, opp_cheat = 0, 0
            for i in range(game_round // 2):      
                if opp_state[i] == 0:
                    opp_cheat += 1
                else:
                    opp_coop += 1
            if opp_cheat >= opp_coop:
                my_action = 0
            else:
                my_action = 1

    elif strategy == "Cooperate-Tester":
        if cur_game_round < game_round // 2:
            my_action = random.randint(0, 1)
        else:
            opp_coop, opp_cheat = 0, 0
            for i in range(game_round // 2):      
                if opp_state[i] == 0:
                    opp_cheat += 1
                else:
                    opp_coop += 1
            if opp_cheat > opp_coop:
                my_action = 0
            else:
                my_action = 1

    elif strategy == "Tranquilizer":
        my_coop, my_cheat = 0, 0
        for ms in my_state:
            if ms == 0:
                my_cheat += 1
            else:
                my_coop += 1
        if (my_cheat + 1) / (my_coop + my_cheat + 1) < 0.25:
            my_action = 0
        else:
            my_action = 1

    elif strategy == "Gradual":
        if cur_game_round == 0:
              my_action = 1
        else:
            opp_cheat = 0
            for os in opp_state:
                if os == 0:
                    opp_cheat += 1
            x, cheat_sum = 1, 0
            for oc in range(opp_cheat):
                cheat_sum += x
                x += 1
            my_cheat = 0
            for ms in my_state:
                if ms == 0:
                    my_cheat += 1
            if cheat_sum > my_cheat:
                my_action = 0
            else:
                my_action = 1

    elif strategy == "Prober":
        if cur_game_round in [0, 1, 2]:
            if cur_game_round == 0:
                my_action = 1
            else:
                my_action = 0
        else:
            prev_three_round = [3, 4, 5]
            while True:
                if cur_game_round in prev_three_round:
                    for i in range(3):
                        prev_three_round[i] -= 3
                    break
                else:
                    for i in range(3):
                        prev_three_round[i] += 3
            if opp_state[prev_three_round[1]] == 1 and opp_state[prev_three_round[2]] == 0:
                my_action = opp_state[-1]
            else:
                if cur_game_round % 3 == 0:
                    my_action = 0
                else:
                    my_action = 1

    elif strategy == "Pavlov":
        if cur_game_round == 0:
            my_action = 1
        else:
            if my_state[-1] == opp_state[-1]:
                my_action = 1
            else:
                my_action = 0
    
    elif strategy == "Mistrust":
        if cur_game_round == 0:
            my_action = 0
        else:
            prev_opp_action = opp_state[-1]
            my_action = prev_opp_action

    elif strategy == "Per-Kind":
        if cur_game_round % 3 in [0, 1]:
            my_action = 1
        else:
            my_action = 0

    elif strategy == "Per-Nasty":
        if cur_game_round % 3 == 0:
            my_action = 1
        else:
            my_action = 0

    return my_action

# %% [markdown]
# # 1. 게임

# %%
from itertools import combinations
from collections import defaultdict
import random
import copy

tournaments = 100
candidates = copy.deepcopy(strategies)
limit = 5
for t in range(tournaments):
    random.shuffle(candidates)
    score_dict = defaultdict(int)
    for i in range(len(candidates)):
        candidates[i] = candidates[i] + "_" + str(i)
    
    for cand1, cand2 in list(combinations(candidates, 2)):
        state = [-1 for _ in range(game_round * 2)]
        cur_game_round = 1
        while cur_game_round <= game_round:
            cand1_action = get_action_of_strategy(state, cand1.split("_")[0], 1)
            cand2_action = get_action_of_strategy(state, cand2.split("_")[0], 2)

            cand1_reward = reward(cand1_action, cand2_action)
            cand2_reward = reward(cand2_action, cand1_action)
            score_dict[cand1] += cand1_reward
            score_dict[cand2] += cand2_reward

            state[(cur_game_round-1) * 2] = cand1_action
            state[((cur_game_round-1) * 2) + 1] = cand2_action

            cur_game_round += 1
    
    print('----Tournament <' + str(t+1) + '>----')
    print('Rank : ')
    rank = sorted(score_dict.items(), key=lambda x:-x[1])
    print(rank)

    print('\nReproduce : ')
    candidates_ = []
    for i in range(limit):
        print('\t' + rank[i][0].split("_")[0])
        candidates_.append(rank[i][0].split("_")[0])
        candidates_.append(rank[i][0].split("_")[0])

    # print('\nCopy : ')
    for i in range(limit, len(candidates) - limit):
    #     print('\t' + rank[i][0].split("_")[0])
        candidates_.append(rank[i][0].split("_")[0])

    print('\nEliminate')
    for i in range(len(candidates) - limit, len(candidates)):
        print('\t' + rank[i][0].split("_")[0])

    candidates = candidates_
    print('\n')

print('\nResult : ')
print(candidates)
# Out:
# ----Tournament <1>----
# Rank :
# [('Gradual_3', 269), ('Copycat_0', 265), ('Cooperate-Downing_17', 265), ('Joss_6', 262), ('All Cooperate_14', 254), ('Pavlov_4', 253), ('Simpleton_16', 252), ('Per-Kind_15', 248), ('Copykitten_11', 247), ('Grudger_10', 244), ('Detective_12', 240), ('Random_18', 227), ('Tranquilizer_19', 226), ('Mistrust_5', 208), ('Cheat-Tester_9', 207), ('Cooperate-Tester_1', 197), ('All Cheat_13', 189), ('Per-Nasty_8', 185), ('Cheat-Downing_7', 181), ('Prober_2', 173)]
#
# Reproduce :
# 	Gradual
# 	Copycat
# 	Cooperate-Downing
# 	Joss
# 	All Cooperate
#
# Eliminate
# 	Cooperate-Tester
# 	All Cheat
# 	Per-Nasty
# 	Cheat-Downing
# 	Prober
#
#
# ----Tournament <2>----
# Rank :
# [('Copycat_7', 348), ('Copycat_13', 341), ('Gradual_19', 334), ('Simpleton_14', 331), ('Joss_4', 330), ('Pavlov_1', 326), ('Gradual_10', 326), ('Cooperate-Downing_5', 324), ('Copykitten_15', 318), ('All Cooperate_0', 317), ('Cooperate-Downing_2', 315), ('All Cooperate_3', 314), ('Detective_11', 302), ('Joss_12', 301), ('Grudger_9', 298), ('Per-Kind_17', 284), ('Tranquilizer_8', 283), ('Cheat-Tester_18', 280), ('Random_16', 237), ('Mistrust_6', 227)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Gradual
# 	Simpleton
# 	Joss
#
# Eliminate
# 	Per-Kind
# 	Tranquilizer
# 	Cheat-Tester
# 	Random
# 	Mistrust
#
#
# ----Tournament <3>----
# Rank :
# [('Gradual_0', 378), ('Copycat_1', 378), ('Copycat_6', 378), ('Joss_11', 378), ('Copycat_15', 378), ('Gradual_17', 378), ('Copycat_19', 378), ('Pavlov_3', 371), ('Simpleton_12', 371), ('Simpleton_16', 371), ('Joss_5', 369), ('Grudger_13', 367), ('Copykitten_14', 363), ('Cooperate-Downing_8', 362), ('Gradual_10', 362), ('Cooperate-Downing_18', 362), ('All Cooperate_2', 359), ('All Cooperate_7', 359), ('Joss_4', 352), ('Detective_9', 306)]
#
# Reproduce :
# 	Gradual
# 	Copycat
# 	Copycat
# 	Joss
# 	Copycat
#
# Eliminate
# 	Cooperate-Downing
# 	All Cooperate
# 	All Cooperate
# 	Joss
# 	Detective
#
#
# ----Tournament <4>----
# Rank :
# [('Copycat_2', 380), ('Grudger_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_6', 380), ('Copycat_11', 380), ('Simpleton_12', 380), ('Gradual_13', 380), ('Gradual_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Gradual_18', 380), ('Copykitten_19', 380), ('Copycat_8', 370), ('Joss_0', 369), ('Pavlov_1', 365), ('Simpleton_14', 365), ('Copycat_5', 360), ('Gradual_10', 348), ('Joss_9', 344), ('Joss_7', 343)]
#
# Reproduce :
# 	Copycat
# 	Grudger
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Simpleton
# 	Copycat
# 	Gradual
# 	Joss
# 	Joss
#
#
# ----Tournament <5>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Gradual_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Simpleton_5', 380), ('Gradual_6', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Grudger_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Grudger_16', 380), ('Copykitten_18', 380), ('Copycat_19', 380), ('Copycat_15', 370), ('Pavlov_7', 365), ('Gradual_17', 364), ('Joss_14', 343)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Gradual
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Pavlov
# 	Gradual
# 	Joss
#
#
# ----Tournament <6>----
# Rank :
# [('Gradual_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Gradual_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Copykitten_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Gradual_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Grudger_14', 380), ('Simpleton_15', 380), ('Grudger_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Gradual
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Gradual
#
# Eliminate
# 	Simpleton
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
#
# ----Tournament <7>----
# Rank :
# [('Gradual_0', 380), ('Copykitten_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Grudger_4', 380), ('Copycat_5', 380), ('Gradual_6', 380), ('Cooperate-Downing_7', 380), ('Gradual_8', 380), ('Copycat_9', 380), ('Gradual_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Cooperate-Downing_14', 380), ('Gradual_15', 380), ('Cooperate-Downing_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Gradual
# 	Copykitten
# 	Copycat
# 	Copycat
# 	Grudger
#
# Eliminate
# 	Gradual
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
#
#
# ----Tournament <8>----
# Rank :
# [('Gradual_0', 380), ('Gradual_1', 380), ('Grudger_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copykitten_7', 380), ('Copykitten_8', 380), ('Gradual_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Gradual_14', 380), ('Grudger_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Gradual_19', 380)]
#
# Reproduce :
# 	Gradual
# 	Gradual
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Grudger
# 	Copycat
# 	Copycat
# 	Copycat
# 	Gradual
#
#
# ----Tournament <9>----
# Rank :
# [('Gradual_0', 380), ('Copycat_1', 380), ('Gradual_2', 380), ('Copykitten_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copykitten_6', 380), ('Copycat_7', 380), ('Grudger_8', 380), ('Grudger_9', 380), ('Gradual_10', 380), ('Gradual_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Cooperate-Downing_14', 380), ('Gradual_15', 380), ('Gradual_16', 380), ('Copycat_17', 380), ('Cooperate-Downing_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Gradual
# 	Copycat
# 	Gradual
# 	Copykitten
# 	Copycat
#
# Eliminate
# 	Gradual
# 	Gradual
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
#
# ----Tournament <10>----
# Rank :
# [('Copycat_0', 380), ('Grudger_1', 380), ('Gradual_2', 380), ('Gradual_3', 380), ('Copykitten_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Grudger_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Gradual_14', 380), ('Gradual_15', 380), ('Copykitten_16', 380), ('Gradual_17', 380), ('Copykitten_18', 380), ('Gradual_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Grudger
# 	Gradual
# 	Gradual
# 	Copykitten
#
# Eliminate
# 	Gradual
# 	Copykitten
# 	Gradual
# 	Copykitten
# 	Gradual
#
#
# ----Tournament <11>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Gradual_2', 380), ('Copycat_3', 380), ('Gradual_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Copykitten_10', 380), ('Gradual_11', 380), ('Grudger_12', 380), ('Gradual_13', 380), ('Gradual_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Copykitten_17', 380), ('Copycat_18', 380), ('Grudger_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Gradual
# 	Copycat
# 	Gradual
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Copykitten
# 	Copycat
# 	Grudger
#
#
# ----Tournament <12>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Gradual_2', 380), ('Gradual_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Grudger_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copykitten_10', 380), ('Gradual_11', 380), ('Copycat_12', 380), ('Gradual_13', 380), ('Grudger_14', 380), ('Copycat_15', 380), ('Gradual_16', 380), ('Gradual_17', 380), ('Gradual_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Gradual
# 	Gradual
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Gradual
# 	Gradual
# 	Gradual
# 	Copycat
#
#
# ----Tournament <13>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Cooperate-Downing_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Grudger_6', 380), ('Gradual_7', 380), ('Grudger_8', 380), ('Gradual_9', 380), ('Gradual_10', 380), ('Gradual_11', 380), ('Copycat_12', 380), ('Gradual_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copykitten_17', 380), ('Gradual_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copykitten
# 	Gradual
# 	Cooperate-Downing
#
#
# ----Tournament <14>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Gradual_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Gradual_7', 380), ('Gradual_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Grudger_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Gradual_15', 380), ('Grudger_16', 380), ('Gradual_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Gradual
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Gradual
# 	Grudger
# 	Gradual
# 	Copycat
# 	Copycat
#
#
# ----Tournament <15>----
# Rank :
# [('Copycat_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Gradual_6', 380), ('Copycat_7', 380), ('Grudger_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Gradual_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Gradual_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Gradual_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Gradual
# 	Copycat
# 	Copycat
# 	Gradual
#
#
# ----Tournament <16>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Grudger_2', 380), ('Copycat_3', 380), ('Gradual_4', 380), ('Gradual_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
# 	Gradual
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <17>----
# Rank :
# [('Gradual_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Gradual_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Grudger_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Gradual_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Cooperate-Downing_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Grudger_19', 380)]
#
# Reproduce :
# 	Gradual
# 	Copycat
# 	Copycat
# 	Gradual
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Grudger
#
#
# ----Tournament <18>----
# Rank :
# [('Copycat_0', 380), ('Gradual_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Gradual_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Gradual_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Gradual_16', 380), ('Copycat_17', 380), ('Gradual_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Gradual
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Gradual
# 	Copycat
# 	Gradual
# 	Cooperate-Downing
#
#
# ----Tournament <19>----
# Rank :
# [('Grudger_0', 380), ('Copycat_1', 380), ('Gradual_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Gradual_5', 380), ('Cooperate-Downing_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Gradual_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Gradual_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Grudger
# 	Copycat
# 	Gradual
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Gradual
# 	Cooperate-Downing
#
#
# ----Tournament <20>----
# Rank :
# [('Grudger_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Gradual_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Grudger_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Gradual_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Gradual_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Gradual_19', 380)]
#
# Reproduce :
# 	Grudger
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Gradual
#
# Eliminate
# 	Gradual
# 	Copycat
# 	Copycat
# 	Copycat
# 	Gradual
#
#
# ----Tournament <21>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Grudger_3', 380), ('Copycat_4', 380), ('Grudger_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Cooperate-Downing_9', 380), ('Copycat_10', 380), ('Grudger_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Gradual_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Gradual_18', 380), ('Gradual_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
#
# Eliminate
# 	Gradual
# 	Copycat
# 	Copycat
# 	Gradual
# 	Gradual
#
#
# ----Tournament <22>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Grudger_5', 380), ('Copycat_6', 380), ('Grudger_7', 380), ('Grudger_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Cooperate-Downing_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Grudger_17', 380), ('Cooperate-Downing_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
#
#
# ----Tournament <23>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Grudger_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Grudger_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Grudger_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Grudger
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Grudger
#
#
# ----Tournament <24>----
# Rank :
# [('Copycat_0', 380), ('Grudger_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Grudger_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Grudger
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
#
#
# ----Tournament <25>----
# Rank :
# [('Copycat_0', 380), ('Cooperate-Downing_1', 380), ('Grudger_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Grudger_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Cooperate-Downing
# 	Grudger
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <26>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Grudger_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Grudger_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Grudger_18', 380), ('Grudger_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Grudger
# 	Grudger
#
#
# ----Tournament <27>----
# Rank :
# [('Grudger_0', 380), ('Cooperate-Downing_1', 380), ('Cooperate-Downing_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Grudger_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Grudger
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Grudger
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <28>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Grudger_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Grudger_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Grudger_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Cooperate-Downing_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
#
#
# ----Tournament <29>----
# Rank :
# [('Copycat_0', 380), ('Grudger_1', 380), ('Cooperate-Downing_2', 380), ('Grudger_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Grudger_16', 380), ('Grudger_17', 380), ('Cooperate-Downing_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Grudger
# 	Cooperate-Downing
# 	Grudger
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Grudger
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
#
#
# ----Tournament <30>----
# Rank :
# [('Grudger_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Grudger_12', 380), ('Copycat_13', 380), ('Grudger_14', 380), ('Grudger_15', 380), ('Cooperate-Downing_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <31>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Grudger_2', 380), ('Grudger_3', 380), ('Cooperate-Downing_4', 380), ('Grudger_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Cooperate-Downing_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Grudger_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Grudger
# 	Grudger
# 	Cooperate-Downing
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <32>----
# Rank :
# [('Grudger_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Grudger_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Grudger_6', 380), ('Cooperate-Downing_7', 380), ('Cooperate-Downing_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Grudger_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Grudger_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
# 	Grudger
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
# 	Copycat
#
#
# ----Tournament <33>----
# Rank :
# [('Copycat_0', 380), ('Grudger_1', 380), ('Copycat_2', 380), ('Grudger_3', 380), ('Grudger_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Grudger_10', 380), ('Cooperate-Downing_11', 380), ('Grudger_12', 380), ('Copycat_13', 380), ('Grudger_14', 380), ('Copycat_15', 380), ('Grudger_16', 380), ('Cooperate-Downing_17', 380), ('Cooperate-Downing_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Grudger
# 	Copycat
# 	Grudger
# 	Grudger
#
# Eliminate
# 	Copycat
# 	Grudger
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
#
#
# ----Tournament <34>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Grudger_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Grudger_6', 380), ('Grudger_7', 380), ('Grudger_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Grudger_12', 380), ('Grudger_13', 380), ('Copycat_14', 380), ('Grudger_15', 380), ('Cooperate-Downing_16', 380), ('Grudger_17', 380), ('Grudger_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Grudger
# 	Cooperate-Downing
# 	Grudger
# 	Grudger
# 	Copycat
#
#
# ----Tournament <35>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Grudger_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Grudger_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Grudger_10', 380), ('Copycat_11', 380), ('Cooperate-Downing_12', 380), ('Grudger_13', 380), ('Grudger_14', 380), ('Grudger_15', 380), ('Grudger_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
#
# Eliminate
# 	Grudger
# 	Grudger
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <36>----
# Rank :
# [('Grudger_0', 380), ('Copycat_1', 380), ('Cooperate-Downing_2', 380), ('Copycat_3', 380), ('Cooperate-Downing_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Grudger_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Grudger_12', 380), ('Grudger_13', 380), ('Copycat_14', 380), ('Grudger_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Grudger
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
#
# Eliminate
# 	Grudger
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <37>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Grudger_2', 380), ('Grudger_3', 380), ('Copycat_4', 380), ('Grudger_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Cooperate-Downing_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Grudger_16', 380), ('Grudger_17', 380), ('Cooperate-Downing_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Grudger
# 	Grudger
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Grudger
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
#
#
# ----Tournament <38>----
# Rank :
# [('Copycat_0', 380), ('Grudger_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Cooperate-Downing_4', 380), ('Grudger_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Grudger_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Copycat_16', 380), ('Grudger_17', 380), ('Grudger_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Grudger
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
#
# Eliminate
# 	Cooperate-Downing
# 	Copycat
# 	Grudger
# 	Grudger
# 	Cooperate-Downing
#
#
# ----Tournament <39>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Grudger_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Grudger_13', 380), ('Copycat_14', 380), ('Grudger_15', 380), ('Copycat_16', 380), ('Cooperate-Downing_17', 380), ('Grudger_18', 380), ('Grudger_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Grudger
# 	Copycat
# 	Cooperate-Downing
# 	Grudger
# 	Grudger
#
#
# ----Tournament <40>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Grudger_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Grudger_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Grudger
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <41>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Grudger_12', 380), ('Grudger_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Grudger_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Grudger_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Grudger
# 	Copycat
# 	Copycat
# 	Grudger
#
#
# ----Tournament <42>----
# Rank :
# [('Grudger_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <43>----
# Rank :
# [('Grudger_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Grudger_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Grudger_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Grudger
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
#
#
# ----Tournament <44>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Cooperate-Downing_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Grudger_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Grudger_16', 380), ('Copycat_17', 380), ('Grudger_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
#
# Eliminate
# 	Copycat
# 	Grudger
# 	Copycat
# 	Grudger
# 	Copycat
#
#
# ----Tournament <45>----
# Rank :
# [('Copycat_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Cooperate-Downing_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Grudger_17', 380), ('Copycat_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Grudger
# 	Copycat
# 	Cooperate-Downing
#
#
# ----Tournament <46>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Cooperate-Downing_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
#
#
# ----Tournament <47>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Cooperate-Downing_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Cooperate-Downing_11', 380), ('Cooperate-Downing_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
#
# ----Tournament <48>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Cooperate-Downing_4', 380), ('Cooperate-Downing_5', 380), ('Cooperate-Downing_6', 380), ('Cooperate-Downing_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Cooperate-Downing_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Copycat_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
#
# Eliminate
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
#
#
# ----Tournament <49>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Cooperate-Downing_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Cooperate-Downing_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
#
# ----Tournament <50>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Cooperate-Downing_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Cooperate-Downing_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <51>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Cooperate-Downing_2', 380), ('Copycat_3', 380), ('Cooperate-Downing_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Copycat_17', 380), ('Cooperate-Downing_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
#
# ----Tournament <52>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Cooperate-Downing_2', 380), ('Cooperate-Downing_3', 380), ('Cooperate-Downing_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Cooperate-Downing_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
#
#
# ----Tournament <53>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Cooperate-Downing_1', 380), ('Cooperate-Downing_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Cooperate-Downing_11', 380), ('Cooperate-Downing_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Cooperate-Downing_17', 380), ('Cooperate-Downing_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
#
#
# ----Tournament <54>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Cooperate-Downing_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Cooperate-Downing_9', 380), ('Cooperate-Downing_10', 380), ('Cooperate-Downing_11', 380), ('Cooperate-Downing_12', 380), ('Copycat_13', 380), ('Cooperate-Downing_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Cooperate-Downing_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
#
# ----Tournament <55>----
# Rank :
# [('Copycat_0', 380), ('Cooperate-Downing_1', 380), ('Cooperate-Downing_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Cooperate-Downing_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Cooperate-Downing_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Cooperate-Downing_16', 380), ('Cooperate-Downing_17', 380), ('Cooperate-Downing_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
#
#
# ----Tournament <56>----
# Rank :
# [('Copycat_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Cooperate-Downing_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Cooperate-Downing_11', 380), ('Copycat_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Copycat_16', 380), ('Cooperate-Downing_17', 380), ('Cooperate-Downing_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
#
# Eliminate
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
#
#
# ----Tournament <57>----
# Rank :
# [('Copycat_0', 380), ('Cooperate-Downing_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Cooperate-Downing_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Cooperate-Downing_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Copycat_17', 380), ('Cooperate-Downing_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
#
#
# ----Tournament <58>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Cooperate-Downing_2', 380), ('Copycat_3', 380), ('Cooperate-Downing_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Cooperate-Downing_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Cooperate-Downing_17', 380), ('Cooperate-Downing_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
#
#
# ----Tournament <59>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Cooperate-Downing_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Cooperate-Downing_8', 380), ('Cooperate-Downing_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Cooperate-Downing_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
#
# ----Tournament <60>----
# Rank :
# [('Cooperate-Downing_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Cooperate-Downing_11', 380), ('Cooperate-Downing_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Copycat_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Cooperate-Downing_19', 380)]
#
# Reproduce :
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
#
#
# ----Tournament <61>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Cooperate-Downing_6', 380), ('Copycat_7', 380), ('Cooperate-Downing_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Cooperate-Downing_11', 380), ('Cooperate-Downing_12', 380), ('Cooperate-Downing_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Cooperate-Downing_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
#
# ----Tournament <62>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Cooperate-Downing_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Cooperate-Downing_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <63>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Cooperate-Downing_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Cooperate-Downing_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Copycat_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
#
# Eliminate
# 	Cooperate-Downing
# 	Copycat
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
#
# ----Tournament <64>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Cooperate-Downing_16', 380), ('Cooperate-Downing_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Cooperate-Downing
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
#
#
# ----Tournament <65>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Cooperate-Downing_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <66>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Cooperate-Downing_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Cooperate-Downing
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <67>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <68>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <69>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <70>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <71>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <72>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <73>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <74>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <75>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <76>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <77>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <78>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <79>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <80>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <81>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <82>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <83>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <84>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <85>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <86>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <87>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <88>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <89>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <90>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <91>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <92>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <93>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <94>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <95>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <96>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <97>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <98>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <99>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
# ----Tournament <100>----
# Rank :
# [('Copycat_0', 380), ('Copycat_1', 380), ('Copycat_2', 380), ('Copycat_3', 380), ('Copycat_4', 380), ('Copycat_5', 380), ('Copycat_6', 380), ('Copycat_7', 380), ('Copycat_8', 380), ('Copycat_9', 380), ('Copycat_10', 380), ('Copycat_11', 380), ('Copycat_12', 380), ('Copycat_13', 380), ('Copycat_14', 380), ('Copycat_15', 380), ('Copycat_16', 380), ('Copycat_17', 380), ('Copycat_18', 380), ('Copycat_19', 380)]
#
# Reproduce :
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
# Eliminate
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
# 	Copycat
#
#
#
# Result :
# ['Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat', 'Copycat']

# %%
agent = REINFORCE()
agent.load_state_dict(torch.load('/content/drive/My Drive/Colab Notebooks/model.pth'))

tournaments = 10
candidates = copy.deepcopy(strategies + ["Agent"])
limit = 5
for t in range(tournaments):
    score_dict = defaultdict(int)
    random.shuffle(candidates)
    for i in range(len(candidates)):
        candidates[i] = candidates[i] + "_" + str(i)

    for cand1, cand2 in list(combinations(candidates, 2)):
        state = [-1 for _ in range(game_round * 2)]
        cur_game_round = 1
        while cur_game_round <= game_round:
            if cand1.split("_")[0] == "Agent": 
                cand1_action = get_action_of_agent(agent, state, 1)
            else:
                cand1_action = get_action_of_strategy(state, cand1.split("_")[0], 1)

            if cand2.split("_")[0] == "Agent": 
                cand2_action = get_action_of_agent(agent, state, 2)
            else:
                cand2_action = get_action_of_strategy(state, cand2.split("_")[0], 2)

            cand1_reward = reward(cand1_action, cand2_action)
            cand2_reward = reward(cand2_action, cand1_action)
            score_dict[cand1] += cand1_reward
            score_dict[cand2] += cand2_reward

            state[(cur_game_round-1) * 2] = cand1_action
            state[((cur_game_round-1) * 2) + 1] = cand2_action

            cur_game_round += 1

    print('----Tournament <' + str(t+1) + '>----')
    print('Rank : ')
    rank = sorted(score_dict.items(), key=lambda x:-x[1])
    print(rank)

    print('\nReproduce : ')
    candidates_ = []
    for i in range(limit):
        print('\t' + rank[i][0].split("_")[0])
        candidates_.append(rank[i][0].split("_")[0])
        candidates_.append(rank[i][0].split("_")[0])

    # print('\nCopy : ')
    for i in range(limit, len(candidates) - limit):
    #     print('\t' + rank[i][0].split("_")[0])
        candidates_.append(rank[i][0].split("_")[0])

    print('\nEliminate')
    for i in range(len(candidates) - limit, len(candidates)):
        print('\t' + rank[i][0].split("_")[0])

    candidates = candidates_
    print('\n')

print('\nResult : ')
print(candidates)
# Out:
# ----Tournament <1>----
# Rank :
# [('Agent_2', 338), ('Copycat_5', 300), ('Gradual_4', 292), ('Joss_1', 285), ('Copykitten_17', 285), ('Cooperate-Downing_11', 282), ('Grudger_8', 281), ('Detective_10', 271), ('Simpleton_3', 266), ('Pavlov_20', 254), ('All Cooperate_14', 253), ('Tranquilizer_12', 248), ('Per-Kind_6', 244), ('Cheat-Tester_15', 220), ('Cooperate-Tester_19', 217), ('Mistrust_13', 207), ('All Cheat_16', 198), ('Cheat-Downing_9', 197), ('Prober_0', 187), ('Per-Nasty_7', 184), ('Random_18', 183)]
#
# Reproduce :
# 	Agent
# 	Copycat
# 	Gradual
# 	Joss
# 	Copykitten
#
# Eliminate
# 	All Cheat
# 	Cheat-Downing
# 	Prober
# 	Per-Nasty
# 	Random
#
#
# ----Tournament <2>----
# Rank :
# [('Agent_20', 393), ('Agent_1', 391), ('Copycat_13', 366), ('Joss_17', 366), ('Copycat_7', 364), ('Grudger_3', 353), ('Joss_11', 351), ('All Cooperate_16', 349), ('Gradual_10', 347), ('Copykitten_12', 347), ('Copykitten_4', 344), ('Pavlov_8', 343), ('Gradual_15', 329), ('Simpleton_2', 327), ('Cooperate-Downing_9', 315), ('Detective_14', 297), ('Tranquilizer_6', 290), ('Per-Kind_5', 289), ('Cooperate-Tester_0', 249), ('Mistrust_18', 247), ('Cheat-Tester_19', 231)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Copycat
# 	Joss
# 	Copycat
#
# Eliminate
# 	Tranquilizer
# 	Per-Kind
# 	Cooperate-Tester
# 	Mistrust
# 	Cheat-Tester
#
#
# ----Tournament <3>----
# Rank :
# [('Agent_5', 400), ('Agent_9', 400), ('Agent_11', 400), ('Agent_19', 400), ('Joss_4', 386), ('Copycat_7', 386), ('Gradual_12', 386), ('Copycat_14', 386), ('Copycat_16', 386), ('Gradual_20', 386), ('Simpleton_1', 379), ('Pavlov_3', 379), ('Joss_10', 377), ('Copycat_18', 376), ('Grudger_0', 375), ('Copykitten_6', 371), ('Copykitten_8', 371), ('All Cooperate_13', 364), ('Cooperate-Downing_17', 360), ('Joss_15', 356), ('Detective_2', 294)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Joss
#
# Eliminate
# 	Copykitten
# 	All Cooperate
# 	Cooperate-Downing
# 	Joss
# 	Detective
#
#
# ----Tournament <4>----
# Rank :
# [('Agent_0', 399), ('Agent_1', 399), ('Agent_2', 399), ('Agent_4', 399), ('Agent_15', 399), ('Agent_19', 399), ('Agent_12', 396), ('Agent_14', 396), ('Pavlov_5', 376), ('Copycat_8', 376), ('Grudger_11', 376), ('Copycat_16', 376), ('Copykitten_18', 376), ('Gradual_20', 376), ('Copycat_3', 366), ('Copycat_6', 366), ('Gradual_7', 360), ('Joss_9', 357), ('Joss_10', 356), ('Simpleton_13', 346), ('Joss_17', 339)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
# Eliminate
# 	Gradual
# 	Joss
# 	Joss
# 	Simpleton
# 	Joss
#
#
# ----Tournament <5>----
# Rank :
# [('Agent_0', 384), ('Agent_1', 384), ('Agent_2', 384), ('Agent_3', 384), ('Agent_4', 384), ('Agent_5', 384), ('Agent_9', 384), ('Agent_11', 384), ('Agent_13', 384), ('Agent_16', 384), ('Agent_17', 384), ('Agent_18', 384), ('Agent_19', 384), ('Copycat_6', 361), ('Grudger_7', 361), ('Gradual_8', 361), ('Copykitten_10', 361), ('Copycat_12', 361), ('Pavlov_14', 361), ('Copycat_15', 361), ('Copycat_20', 361)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
# Eliminate
# 	Copykitten
# 	Copycat
# 	Pavlov
# 	Copycat
# 	Copycat
#
#
# ----Tournament <6>----
# Rank :
# [('Agent_1', 369), ('Agent_2', 369), ('Agent_3', 369), ('Agent_4', 369), ('Agent_5', 369), ('Agent_6', 369), ('Agent_7', 369), ('Agent_9', 369), ('Agent_10', 369), ('Agent_11', 369), ('Agent_12', 369), ('Agent_13', 369), ('Agent_14', 369), ('Agent_15', 369), ('Agent_17', 369), ('Agent_18', 369), ('Agent_19', 369), ('Agent_20', 369), ('Gradual_0', 346), ('Copycat_8', 346), ('Grudger_16', 346)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
# Eliminate
# 	Agent
# 	Agent
# 	Gradual
# 	Copycat
# 	Grudger
#
#
# ----Tournament <7>----
# Rank :
# [('Agent_0', 360), ('Agent_1', 360), ('Agent_2', 360), ('Agent_3', 360), ('Agent_4', 360), ('Agent_5', 360), ('Agent_6', 360), ('Agent_7', 360), ('Agent_8', 360), ('Agent_9', 360), ('Agent_10', 360), ('Agent_11', 360), ('Agent_12', 360), ('Agent_13', 360), ('Agent_14', 360), ('Agent_15', 360), ('Agent_16', 360), ('Agent_17', 360), ('Agent_18', 360), ('Agent_19', 360), ('Agent_20', 360)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
# Eliminate
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
#
# ----Tournament <8>----
# Rank :
# [('Agent_0', 360), ('Agent_1', 360), ('Agent_2', 360), ('Agent_3', 360), ('Agent_4', 360), ('Agent_5', 360), ('Agent_6', 360), ('Agent_7', 360), ('Agent_8', 360), ('Agent_9', 360), ('Agent_10', 360), ('Agent_11', 360), ('Agent_12', 360), ('Agent_13', 360), ('Agent_14', 360), ('Agent_15', 360), ('Agent_16', 360), ('Agent_17', 360), ('Agent_18', 360), ('Agent_19', 360), ('Agent_20', 360)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
# Eliminate
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
#
# ----Tournament <9>----
# Rank :
# [('Agent_0', 360), ('Agent_1', 360), ('Agent_2', 360), ('Agent_3', 360), ('Agent_4', 360), ('Agent_5', 360), ('Agent_6', 360), ('Agent_7', 360), ('Agent_8', 360), ('Agent_9', 360), ('Agent_10', 360), ('Agent_11', 360), ('Agent_12', 360), ('Agent_13', 360), ('Agent_14', 360), ('Agent_15', 360), ('Agent_16', 360), ('Agent_17', 360), ('Agent_18', 360), ('Agent_19', 360), ('Agent_20', 360)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
# Eliminate
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
#
# ----Tournament <10>----
# Rank :
# [('Agent_0', 360), ('Agent_1', 360), ('Agent_2', 360), ('Agent_3', 360), ('Agent_4', 360), ('Agent_5', 360), ('Agent_6', 360), ('Agent_7', 360), ('Agent_8', 360), ('Agent_9', 360), ('Agent_10', 360), ('Agent_11', 360), ('Agent_12', 360), ('Agent_13', 360), ('Agent_14', 360), ('Agent_15', 360), ('Agent_16', 360), ('Agent_17', 360), ('Agent_18', 360), ('Agent_19', 360), ('Agent_20', 360)]
#
# Reproduce :
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
# Eliminate
# 	Agent
# 	Agent
# 	Agent
# 	Agent
# 	Agent
#
#
#
# Result :
# ['Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent', 'Agent']
